# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data1.csv")

# %%
df.head()
# Out:
#   Region  Month  Year   Plant Name              Plant Country  Vendor Code  \
# 0    USA      1  2023  Chicago MFG  United States of America          2000
# 1    USA      1  2023  Chicago MFG  United States of America         15000
# 2    USA      1  2023  Chicago MFG  United States of America         15000
# 3    USA      1  2023  Chicago MFG  United States of America         15000
# 4    USA      1  2023  Chicago MFG  United States of America          8850
#
#               Vendor name            Vendor Country     Commodity    Buyer  \
# 0   Whirlpool 2000 Vendor            United Kingdom         Racks     Maci
# 1  Whirlpool 15000 Vendor  United States of America       Service  Jovanni
# 2  Whirlpool 15000 Vendor  United States of America        Rubber  Jovanni
# 3  Whirlpool 15000 Vendor  United States of America        Rubber  Jovanni
# 4   Whirlpool 8850 Vendor                     China  Not Assigned     Mila
#
#    Part_Code  Payment_Days         Country of Origin  Quantity   \
# 0  M98200088           120                    Mexico       700
# 1  M65107167            90  United States of America    10,000
# 2  M45604979            90  United States of America    10,000
# 3  M81904052            90  United States of America   100,000
# 4  M98556502           120                    Brazil     3,200
#
#   Unit of Measure  Price per unit   PO_Currency   Exchange Rate in USD   \
# 0              EA            23.40          USD                     1.0
# 1              EA             0.74          USD                     1.0
# 2              EA             0.15          USD                     1.0
# 3              EA             0.19          USD                     1.0
# 4              EA             2.30          USD                     1.0
#
#    Spend_USD
# 0     16,380
# 1      7,400
# 2      1,450
# 3     19,300
# 4      7,360

# %%
df.tail()
# Out:
#       Region  Month  Year      Plant Name              Plant Country  \
# 52536    USA     12  2023  California MFG  United States of America
# 52537    USA     12  2023  California MFG  United States of America
# 52538    USA     12  2023  California MFG  United States of America
# 52539    USA     12  2023  California MFG  United States of America
# 52540    USA     12  2023  California MFG  United States of America
#
#        Vendor Code             Vendor name Vendor Country     Commodity  \
# 52536        17000  Whirlpool 17000 Vendor         Poland  Not Assigned
# 52537         7450   Whirlpool 7450 Vendor        Germany     Chemicals
# 52538         7450   Whirlpool 7450 Vendor        Germany     Chemicals
# 52539         7450   Whirlpool 7450 Vendor        Germany     Chemicals
# 52540         7450   Whirlpool 7450 Vendor        Germany     Chemicals
#
#         Buyer  Part_Code  Payment_Days Country of Origin  Quantity   \
# 52536    Jade  M81002253           150            Brazil    62,936
# 52537  Hadlee  M24710773            90            Mexico     2,228
# 52538  Hadlee  M86411317            90            Mexico    32,656
# 52539  Hadlee  M70548302            90            Mexico       133
# 52540  Hadlee  M27811388            90            Mexico     4,082
#
#       Unit of Measure  Price per unit   PO_Currency   Exchange Rate in USD   \
# 52536              KG            17.47          USD                     1.0
# 52537              KG            37.26          USD                     1.0
# 52538              KG            15.87          USD                     1.0
# 52539              KG            18.57          USD                     1.0
# 52540              KG            20.99          USD                     1.0
#
#         Spend_USD
# 52536   1,099,299
# 52537      83,011
# 52538     518,249
# 52539       2,475
# 52540      85,688

# %%
try:
    data = pd.read_csv(file_path, encoding='utf-8')
except UnicodeDecodeError:
    # If utf-8 encoding fails, try ISO-8859-1 (also known as latin1) encoding
    data = pd.read_csv(file_path, encoding='ISO-8859-1')

# Print information about the DataFrame
data.info()

# Calculate correlation matrix
correlation_matrix = data.corr()

# Create a heatmap to visualize the correlations
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title("Correlation Matrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 try:
# ----> 2     data = pd.read_csv(file_path, encoding='utf-8')
#       3 except UnicodeDecodeError:
#       4     # If utf-8 encoding fails, try ISO-8859-1 (also known as latin1) encoding
#       5     data = pd.read_csv(file_path, encoding='ISO-8859-1')
#
# NameError: name 'file_path' is not defined
